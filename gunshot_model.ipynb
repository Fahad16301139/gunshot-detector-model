# %%
pip install librosa numpy

# %%
pip install tensorflow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install pydub

# %%
# Make sure the path matches the location of the file in your Google Drive
path_to_file = "/content/drive/MyDrive/gunshot audio samples/"

# %%
# !ffmpeg -i '/content/drive/MyDrive/gunshot audio samples/input.mp3' '/content/output.wav'
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
import os

# List all files in the directory
files = os.listdir(path_to_audio_files)

# Print the files
for file in files:
    print(file)
# Out:
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com.mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (1).mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (2).mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (3).mp3
# 12-Gauge-Pump-Action-Shotgun-Far-Gunshot-A-www.fesliyanstudios.com.mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (4).mp3
# 12-Gauge-Pump-Action-Shotgun-Far-Gunshot-A-www.fesliyanstudios.com (1).mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-B-www.fesliyanstudios.com.mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-B-www.fesliyanstudios.com (1).mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-B-www.fesliyanstudios.com (2).mp3
# 12-Gauge-Pump-Action-Shotgun-Far-Gunshot-B-www.fesliyanstudios.com.mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-B-www.fesliyanstudios.com (3).mp3
# ...

# %%
# !ffmpeg -i 'input.mp3' 'output.wav'
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
import librosa
import numpy as np

y, sr = librosa.load('/content/output.wav')
mfccs = librosa.feature.mfcc(y=y, sr=sr)

# %%
noise = np.random.randn(len(y))
y_noisy = y + 0.005 * noise

# %%
y_pitch = librosa.effects.pitch_shift(y, n_steps=4, sr=sr)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_to_audio_files = "/content/drive/MyDrive/gunshot audio samples/"

# %%
import os

# List all files in the directory
files = os.listdir(path_to_audio_files)

# Print the files
for file in files:
    print(file)
# Out:
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com.mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (1).mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (2).mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (3).mp3
# 12-Gauge-Pump-Action-Shotgun-Far-Gunshot-A-www.fesliyanstudios.com.mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (4).mp3
# 12-Gauge-Pump-Action-Shotgun-Far-Gunshot-A-www.fesliyanstudios.com (1).mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-B-www.fesliyanstudios.com.mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-B-www.fesliyanstudios.com (1).mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-B-www.fesliyanstudios.com (2).mp3
# 12-Gauge-Pump-Action-Shotgun-Far-Gunshot-B-www.fesliyanstudios.com.mp3
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-B-www.fesliyanstudios.com (3).mp3
# ...

# %%
from pydub import AudioSegment
import os

# Directory containing MP3 files in your Google Drive
mp3_directory = '/content/drive/MyDrive/gunshot audio samples'
# Directory where you want to save WAV files in your Google Drive
wav_directory = '/content/drive/MyDrive/gunshot audio samples/wav'

# Ensure the WAV directory exists
os.makedirs(wav_directory, exist_ok=True)

# Convert MP3 to WAV
for filename in os.listdir(mp3_directory):
    if filename.endswith('.mp3'):
        mp3_path = os.path.join(mp3_directory, filename)
        wav_path = os.path.join(wav_directory, filename.replace('.mp3', '.wav'))
        # Load MP3 file
        audio = AudioSegment.from_mp3(mp3_path)
        # Export as WAV
        audio.export(wav_path, format='wav')

# %%
import librosa
import numpy as np

# Function to extract MFCCs from an audio file
def extract_features(file_path):
    try:
        audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast')
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccs_processed = np.mean(mfccs.T,axis=0)

    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None

    return mfccs_processed

# Directory where you have saved the WAV files
wav_directory = '/content/drive/MyDrive/gunshot audio samples/wav'

# List for holding features and labels
features = []

# Iterate over all the WAV files and extract features
for filename in os.listdir(wav_directory):
    if filename.endswith('.wav'):
        file_path = os.path.join(wav_directory, filename)

        # Extract features and store them in a list
        data = extract_features(file_path)
        if data is not None:
            features.append(data)
# Out:
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# ...

# %%
import subprocess

# Replace 'file.mp3' with the path to your actual file
file_path = "/content/drive/MyDrive/gunshot audio samples/Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3"

# Run the ffmpeg command
result = subprocess.run(['ffmpeg', '-v', 'error', '-i', file_path, '-f', 'null', '-'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# Print any errors
print("stdout:", result.stdout.decode())
print("stderr:", result.stderr.decode())
# Out:
# stdout:
# stderr:

# %%
import os

# Replace this with the path to the directory you want to check
wav_directory = '/content/drive/MyDrive/gunshot audio samples/wav'

# Check if the directory exists
if not os.path.exists(wav_directory):
    print(f"The directory {wav_directory} does not exist.")
else:
    print(f"The directory {wav_directory} exists.")

    # Check if the directory is accessible by listing its contents
    try:
        files = os.listdir(wav_directory)
        print(f"Access granted. Contents of {wav_directory}:")
        for f in files:
            print(f)
    except PermissionError:
        print(f"Permission denied: Unable to access the contents of {wav_directory}.")
# Out:
# The directory /content/drive/MyDrive/gunshot audio samples/wav exists.
# Access granted. Contents of /content/drive/MyDrive/gunshot audio samples/wav:
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com.wav
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (1).wav
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (2).wav
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (3).wav
# 12-Gauge-Pump-Action-Shotgun-Far-Gunshot-A-www.fesliyanstudios.com.wav
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (4).wav
# 12-Gauge-Pump-Action-Shotgun-Far-Gunshot-A-www.fesliyanstudios.com (1).wav
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-B-www.fesliyanstudios.com.wav
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-B-www.fesliyanstudios.com (1).wav
# 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-B-www.fesliyanstudios.com (2).wav
# 12-Gauge-Pump-Action-Shotgun-Far-Gunshot-B-www.fesliyanstudios.com.wav
# ...

# %%
import librosa
import numpy as np

# Function to extract MFCCs from an audio file
def extract_features(file_path):
    try:
        audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast')
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccs_processed = np.mean(mfccs.T,axis=0)

    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None

    return mfccs_processed

# Directory where you have saved the WAV files
wav_directory = '/content/drive/MyDrive/gunshot audio samples/wav'

# List for holding features and labels
features = []

# Iterate over all the WAV files and extract features
for filename in os.listdir(wav_directory):
    if filename.endswith('.wav'):
        file_path = os.path.join(wav_directory, filename)

        # Extract features and store them in a list
        data = extract_features(file_path)
        if data is not None:
            features.append(data)
# Out:
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# ...

# %%
for filename in os.listdir(wav_directory):
    if filename.endswith('.wav'):
        file_path = os.path.join(wav_directory, filename)
        try:
            # Extract features and store them in a list
            data = extract_features(file_path)
            if data is not None:
                features.append(data)
        except Exception as e:
            print(f"Error encountered while parsing file: {filename}")
            print(e)
# Out:
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# Error encountered while parsing file:  Machine-Gun-Automatic-Fire-A-www.fesliyanstudios.com (2).mp3
# ...

# %%
import librosa
import numpy as np
import os

# Function to extract MFCCs from an audio file
def extract_features(file_path):
    try:
        audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast')
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccs_processed = np.mean(mfccs.T, axis=0)
    except Exception as e:
        print("Error encountered while parsing file: ", file_path)
        print(e)  # Print the actual error message
        return None  # Return None to indicate the failure
    return mfccs_processed

# Directory where you have saved the WAV files
wav_directory = '/content/drive/MyDrive/gunshot audio samples/wav'  # Make sure this path is correct

# List for holding features and labels
features = []

# Iterate over all the WAV files and extract features
for filename in os.listdir(wav_directory):
    if filename.endswith('.wav'):
        file_path = os.path.join(wav_directory, filename)
        data = extract_features(file_path)
        if data is not None:
            features.append(data)
        else:
            print(f"Skipping file: {filename}")  # Indicate that the file is being skipped
# Out:
# Error encountered while parsing file:  /content/drive/MyDrive/gunshot audio samples/wav/12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com.wav
# No module named 'resampy'
#
# This error is lazily reported, having originally occured in
#   File /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py, line 32, in <module>
#
# ----> resampy = lazy.load("resampy")
# Skipping file: 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com.wav
# Error encountered while parsing file:  /content/drive/MyDrive/gunshot audio samples/wav/12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (1).wav
# No module named 'resampy'
#
# This error is lazily reported, having originally occured in
#   File /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py, line 32, in <module>
#
# ----> resampy = lazy.load("resampy")
# Skipping file: 12-Gauge-Pump-Action-Shotgun-Close-Gunshot-A-www.fesliyanstudios.com (1).wav
# ...
